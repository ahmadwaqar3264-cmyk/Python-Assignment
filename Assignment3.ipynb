# %% [markdown]
# # Task: Guess the Number Game
# Description:
# Write a Python program that generates a random number between 1 and 100. The user should then repeatedly guess the number until they guess it correctly. After each guess, the program should provide feedback to the user, indicating whether their guess is too high, too low, or correct. Once the correct number is guessed, the program should print the number of attempts it took the user to guess the correct number. Hints:
# 1.Use a while loop to repeatedly prompt the user for their guess until they guess the correct number.
# 2.Use the random module to generate a random number between 1 and 100.
# 3.Provide feedback to the user after each guess, indicating whether their guess is too high, too low, or correct.
# 4.Count the number of attempts it takes the user to guess the correct number and print this count when the correct number is guessed.

# %%
import random

number = random.randint(1, 100)
attempts = 0

while True:
    guess = int(input("Guess a number (1 se 100 ke beech): "))
    attempts += 1

    if guess > number:
        print("Too high")
    elif guess < number:
        print("Too low")
    else:
        print("Correct guess!")
        print("Total attempts:", attempts)
        break
# Out:
# Guess a number (1 se 100 ke beech):  3
# Too low
# Guess a number (1 se 100 ke beech):  70
# Too low
# Guess a number (1 se 100 ke beech):  90
# Too low
# Guess a number (1 se 100 ke beech):  95
# Too high
# Guess a number (1 se 100 ke beech):  91
# Too low
