# %%
# Write a function to convert a given decimal number to its binary representation.  Example
# Input: decimal = 10
# Expected Output: 1010 (the binary representation of 10 is 1010)  Example
# Input: decimal = 5

# %%
print(bin(124))
# Out:
# 0b1111100

# %%
decimal = 124
binary = ""
while decimal > 0:
    remainder = decimal % 2
    binary = str(remainder) + binary
    decimal = decimal // 2
print(binary)
# Out:
# 1111100

# %%
def decimal_to_binary(decimal:int) ->int:
    """
    This function convert a decimal to its binary representation.
    """
    if not isinstance(decimal,int):
        raise TypeError("Input must be an integer")
    if decimal == 0:
        return 0
    binary = ""
    while decimal > 0:
        remainder = decimal % 2
        binary = str(remainder) + binary
        decimal = decimal // 2
    return binary  
if __name__ == "__main__":
    decimal = 124
    try:
        result = decimal_to_binary(decimal)
        print("Decimal is", result)
    except TypeError as error:
        print("Error",e)
    except Exception as error:
        print("Error",e)
# Out:
# Decimal is 1111100
