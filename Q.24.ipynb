# %%
# Write a function that removes all whitespace characters (spaces, tabs, newlines) from a given string.  Example:
# Input: "    \n        This    \t        is   \r       python     "
# Expected Output: This is python

# %%
text = "    \n        This    \t        is   \r       python     "
result = ""
prev_space = False
for char in text.strip():
    if not char.isspace():
        result = result + char
        prev_space = False
    else:
        if prev_space == False:
            result = result + " "
            prev_space = True
print(result)
# Out:
# This is python

# %%
def normalize_whitespace(text:str) -> str:
    """
    This function normalize whitespace in a string.
    """
    if not isinstance(text,str):
        raise TypeError("Input must be string")
    result = ""
    prev_space = False
    for char in text.strip():
        if not char.isspace():
            result = result + char
            prev_space = False
        else:
            if prev_space == False:
                result = result + " "
                prev_space = True
    return result
if __name__ == "__main__":
    text = "    \n        This    \t        is   \r       python     "
    try:
        result = normalize_whitespace(text)
        print(result)
    except TypeError as e:
        print("Error:",e)
    except Exception as e:
        print("Error:",error)
# Out:
# This is python
