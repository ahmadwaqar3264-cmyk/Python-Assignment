# %%
# 18. Binary Search Implementation
# Write a function that performs binary search on a sorted list and returns the index of the
# target element or -1 if not found.  Example
# Input: sorted_list = [1, 2, 3, 4, 5, 6], target = 4
# Expected Output: 3 (since 4 is at index 3)  Example
# Input: sorted_list = [10, 20, 30, 40, 50], target = 25
# Expected Output: -1 (since 25 is not in the list)

# %%
sorted_list = [2, 5, 8, 12, 16, 23, 38, 45, 56, 67, 78, 89, 90, 95, 100]
target = 95
low = 0
high = len(sorted_list) - 1
while low <= high:
    mid = (low + high)//2
    if sorted_list[mid] == target:
        print(mid)
        break
    elif target < sorted_list[mid]:
        high = mid - 1
    else:
        low = mid + 1
else:
    print(-1)
# Out:
# 13

# %%
def binary_search(sorted_list: list, target: int) -> int:
    """
    This function perform binary search on a sorted list.
    """
    if not isinstance(sorted_list, list):
        raise TypeError("Sorted list must a list")
    if not isinstance(target, int):
        raise TypeError("Input must be an integer")
        
    low = 0
    high = len(sorted_list) - 1
    while low <= high:
        mid = (low + high)//2
        if sorted_list[mid] == target:
            return mid
        elif target < sorted_list[mid]:
            high = mid - 1
        else:
            low = mid + 1
    return - 1

if __name__ == "__main__":
    sorted_list = [2, 5, 8, 12, 16, 23, 38, 45, 56, 67, 78, 89, 90, 95, 100]
    target = 56
    try:
        result = binary_search(sorted_list, target)
        print(result)
    except TypeError as e:
        print("Error", e)
    except Exception as e:
        print(e)
# Out:
# 8
